# %%
import numpy as np

# %%
from Snake import AI
# Out:
# Using TensorFlow backend.

# %%
weights = np.array([np.random.uniform(-100, 100) for x in range(372)])

# %%
snake = AI.create_nn(weights)

# %%
snake(np.array([np.random.uniform(-5,5) for x in range(32)]).reshape(1, 32))
# Out:
# array([[0., 1., 0., 0.]], dtype=float32)
