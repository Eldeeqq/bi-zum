# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib nbagg
from matplotlib import animation, rc, cm
import matplotlib.colors as colors
import IPython, io, urllib
rc('animation', html='html5')

# %%
width=height= 25

# %%
mapa = [[0 for x in range(width)]for y in range(height)]

# %%
for x in range(len(mapa[0])):
    mapa[0][x] = 3
for x in range(len(mapa[-1])):
    mapa[-1][x] = 3

# %%
for x in mapa:
    x[0]=x[-1]= 3

# %%
mapa[5][5] = 1

# %%
mapa[4][2] =2
mapa[4][3] =2
mapa[4][4] =2

# %%
class A:
    def title(self):
        return str(np.random.randint(0, 100))

# %%
cmap = colors.ListedColormap(['white', 'red', 'green', '#cb7341'])
boundaries = [-.9, -0.75, 0.5, .9]
norm = colors.BoundaryNorm(boundaries, cmap.N, clip=True)

# %%
a = A()

# %%
a.title()
# Out:
# '94'

# %%
mapa = np.array([[3, 3, 3, 3, 3, 3, 3, 3, 3, 3],
       [3, 0, 0, 0, 0, 0, 0, 0, 0, 3],
       [3, 0, 0, 0, 0, 0, 0, 0, 0, 3],
       [3, 0, 0, 0, 0, 0, 0, 0, 0, 3],
       [3, 0, 0, 0, 0, 0, 0, 0, 0, 3],
       [3, 0, 0, 0, 0, 0, 0, 0, 0, 3],
       [3, 0, 1, 0, 2, 0, 0, 0, 0, 3],
       [3, 0, 0, 0, 0, 0, 0, 0, 0, 3],
       [3, 0, 0, 0, 0, 0, 0, 0, 0, 3],
       [3, 3, 3, 3, 3, 3, 3, 3, 3, 3]])

# %%
def dec(ax):
    def update(i):
        ax.cla()
#         mapa[6][i%width] = 1
#         mapa[6][max(0, (i-1)%width)] = 0
        ax.imshow(np.array(mapa), cmap=cmap, interpolation='nearest', animated=True, extent=(0,width,0,height))
        ax.set_title(f"score: {a.title()}")
        ax.axis('off');
        return ax
    return update

# %%
fig, ax = plt.subplots();
anim = animation.FuncAnimation(fig, dec(ax), interval=100);
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-dadac7d0b264> in <module>
# ----> 1 fig, ax = plt.subplots();
#       2 anim = animation.FuncAnimation(fig, dec(ax), interval=100, repeat=False);
#       3 plt.axis('off')
#       4 plt.show()
#
# NameError: name 'plt' is not defined

# %%
del anim
